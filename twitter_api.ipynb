# %%
# pip3 install --upgrade git+https://github.com/tweepy/tweepy.git
import tweepy

from loadCredentials import loadCredentials

cred = loadCredentials(["TWITTER_API_KEY","TWITTER_API_SECRET","TWITTER_ACCESS_TOKEN","TWITTER_ACCESS_TOKEN_SECRET"])

auth = tweepy.OAuthHandler(cred["TWITTER_API_KEY"], cred["TWITTER_API_SECRET"])
auth.set_access_token(cred["TWITTER_ACCESS_TOKEN"], cred["TWITTER_ACCESS_TOKEN_SECRET"])
api = tweepy.API(auth)
# Out:
# {'TWITTER_API_KEY': 'Y2hTyCymBDQ9PhiBQyRPTBKxl', 'TWITTER_API_SECRET': 'WLJqxGm8Gz8AJDMILgGvrUtoW64bJHZNzTrbo2NFbrfUV3cYNt', 'TWITTER_ACCESS_TOKEN': '117063633-5lnKjpyrfJa63CdCp5GiwgucmYG23VSFL03GdgN4', 'TWITTER_ACCESS_TOKEN_SECRET': 'kfGmDRgqBGvODn1unMxM8h0a41P0ucrZDjvzMmyGxgcAP'}

# %%
import pandas as pd
from pandas.io.json import json_normalize
twt = api.search("julio iglesias")
tweets = pd.DataFrame([pd.Series(tweet._json) for tweet in twt])

display(tweets.columns)
display(tweets.head(5))
display(tweets[['created_at','text','user']].head(5))
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities',
#        'metadata', 'source', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo',
#        'coordinates', 'place', 'contributors', 'retweeted_status',
#        'is_quote_status', 'retweet_count', 'favorite_count', 'favorited',
#        'retweeted', 'lang', 'possibly_sensitive', 'extended_entities'],
#       dtype='object')
#                        created_at                   id               id_str  \
# 0  Tue Oct 30 12:09:31 +0000 2018  1057243096226979840  1057243096226979840
# 1  Tue Oct 30 12:08:27 +0000 2018  1057242826541539329  1057242826541539329
# 2  Tue Oct 30 11:55:18 +0000 2018  1057239517948768256  1057239517948768256
# 3  Tue Oct 30 11:48:03 +0000 2018  1057237693799784448  1057237693799784448
# 4  Tue Oct 30 11:45:20 +0000 2018  1057237009373245441  1057237009373245441
#
#                                                 text  truncated  \
# 0  RT @montalvan47: @canalN_ @LDavelouis Que no s...      False
# 1  @avanzandoglobal @padelriol 🤦🏽‍♀️ hasta Julio ...      False
# 2  Ni un día de lluvia sin escuchar 'La carretera...      False
# 3  MANEJAR\n\n+ \n\nLLUVIA\n\n+\n\nESTE TEMA\n\nN...       True
# 4  @Pablo_Iglesias_ Y que me dices de la mierda d...       True
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'es', 'result_type': 're...
# 1  {'iso_language_code': 'es', 'result_type': 're...
# 2  {'iso_language_code': 'es', 'result_type': 're...
# 3  {'iso_language_code': 'es', 'result_type': 're...
# 4  {'iso_language_code': 'es', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/android" ...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...           1.057240e+18
# 2  <a href="http://twitter.com" rel="nofollow">Tw...                    NaN
# 3  <a href="http://twitter.com/download/android" ...                    NaN
# 4  <a href="http://twitter.com/download/android" ...           1.056821e+18
#
#   in_reply_to_status_id_str        ...          contributors  \
# 0                      None        ...                  None
# 1       1057239852922667008        ...                  None
# 2                      None        ...                  None
# 3                      None        ...                  None
# 4       1056820873624276992        ...                  None
#
#                                     retweeted_status is_quote_status  \
# 0  {'created_at': 'Tue Oct 30 05:32:43 +0000 2018...           False
# 1                                                NaN           False
# 2                                                NaN           False
# 3                                                NaN           False
# 4                                                NaN           False
#
#   retweet_count favorite_count favorited retweeted lang possibly_sensitive  \
# 0             2              0     False     False   es                NaN
# 1             0              0     False     False   es                NaN
# 2             0              3     False     False   es                NaN
# 3             0              0     False     False   es              False
# 4             0              0     False     False   es                NaN
#
#    extended_entities
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 27 columns]
#                        created_at  \
# 0  Tue Oct 30 12:09:31 +0000 2018
# 1  Tue Oct 30 12:08:27 +0000 2018
# 2  Tue Oct 30 11:55:18 +0000 2018
# 3  Tue Oct 30 11:48:03 +0000 2018
# 4  Tue Oct 30 11:45:20 +0000 2018
#
#                                                 text  \
# 0  RT @montalvan47: @canalN_ @LDavelouis Que no s...
# 1  @avanzandoglobal @padelriol 🤦🏽‍♀️ hasta Julio ...
# 2  Ni un día de lluvia sin escuchar 'La carretera...
# 3  MANEJAR\n\n+ \n\nLLUVIA\n\n+\n\nESTE TEMA\n\nN...
# 4  @Pablo_Iglesias_ Y que me dices de la mierda d...
#
#                                                 user
# 0  {'id': 4888571943, 'id_str': '4888571943', 'na...
# 1  {'id': 972894688016347136, 'id_str': '97289468...
# 2  {'id': 2213887352, 'id_str': '2213887352', 'na...
# 3  {'id': 822945222778818560, 'id_str': '82294522...
# 4  {'id': 744178112305467392, 'id_str': '74417811...

# %%
json_normalize(tweets['user'])['screen_name']
# Out:
# 0     Maradel07044308
# 1      SaritaColonia9
# 2        Mondo_Moyano
# 3        soysirwalter
# 4           auroroski
# 5         dayatarmizi
# 6              Xupe11
# 7         SorsieMorsi
# 8          sanlagenia
# 9     Frances34723486
# 10    Frances34723486
# Name: screen_name, dtype: object

# %%
tweets['user'] = json_normalize(tweets['user'])['screen_name']

# %%
display(tweets[['created_at','text','user']].head(5))
print(tweets['text'].values)
print(len(tweets))
# Out:
#                        created_at  \
# 0  Tue Oct 30 12:09:31 +0000 2018
# 1  Tue Oct 30 12:08:27 +0000 2018
# 2  Tue Oct 30 11:55:18 +0000 2018
# 3  Tue Oct 30 11:48:03 +0000 2018
# 4  Tue Oct 30 11:45:20 +0000 2018
#
#                                                 text             user
# 0  RT @montalvan47: @canalN_ @LDavelouis Que no s...  Maradel07044308
# 1  @avanzandoglobal @padelriol 🤦🏽‍♀️ hasta Julio ...   SaritaColonia9
# 2  Ni un día de lluvia sin escuchar 'La carretera...     Mondo_Moyano
# 3  MANEJAR\n\n+ \n\nLLUVIA\n\n+\n\nESTE TEMA\n\nN...     soysirwalter
# 4  @Pablo_Iglesias_ Y que me dices de la mierda d...        auroroski
# ['RT @montalvan47: @canalN_ @LDavelouis Que no se exacerbe la cólera popular, podría suceder lo de los hermanos Gutierrez, colgados en torres…'
#  '@avanzandoglobal @padelriol 🤦🏽\u200d♀️ hasta Julio Iglesias opina...'
#  "Ni un día de lluvia sin escuchar 'La carretera' de Julio Iglesias."
#  'MANEJAR\n\n+ \n\nLLUVIA\n\n+\n\nESTE TEMA\n\nNADA PUEDE MALIR SAL.\n\nAquí te va una canción para ti… Lo Mejor de Tu Vida de Ju… https://t.co/MR43v9cNP6'
#  '@Pablo_Iglesias_ Y que me dices de la mierda de izquierda que tienen alli\nY que me dices de los infiltrados para la… https://t.co/DYfiCvK0f9'
#  'RT @addiems: Julio Iglesias https://t.co/K5GmlMgaXr'
#  '@RubenCtGt @BobEstropajo No estuvo Julio Iglesias de gira por Andalucia hace 8 años mas o menos?'
#  'Hoy comenzamos con Visor Fest! 🤗 Estás preparado??\n💪 Te esperamos!!!! 😋\n📍 Auditorio Julio Iglesias, Benidorm… https://t.co/mjf0KDPfaL'
#  'RT @SansinenaSyD: 16.08 Juegan en Cerri Sansinena- Pacífico por la 13° del Clausura Julio Romero.\nÁrbitro: Rubén Molina.\nAsist: Mario Igles…'
#  'JULIO IGLESIAS Bimba https://t.co/Z883qetq0n via @YouTube'
#  'MANUELA -JULIO IGLESIAS ( ITALIANO) LYRICS https://t.co/ijW6ElSzZh via @YouTube']
# 11
